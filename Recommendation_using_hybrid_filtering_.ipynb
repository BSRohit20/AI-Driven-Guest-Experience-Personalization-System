# %%
# !pip install pandas numpy scikit-learn sqlalchemy gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 MB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.4/321.4 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 25.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 1.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler
from sqlalchemy import create_engine
import gradio as gr

# %%
from google.colab import files
uploaded = files.upload()

data = pd.read_csv(list(uploaded.keys())[0])
data.head()
# Out:
#      <input type="file" id="files-4a4dc9a7-eae4-4a12-b399-962090597f02" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a4dc9a7-eae4-4a12-b399-962090597f02">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
tfidf = TfidfVectorizer(stop_words='english')
data['Preferences'] = data['Preferences'].fillna('')
tfidf_matrix = tfidf.fit_transform(data['Preferences'])

# %%
numerical_features = ['ProductQuality', 'ServiceQuality', 'PurchaseFrequency', 'SatisfactionScore']
data[numerical_features] = data[numerical_features].fillna(0)
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data[numerical_features])

# %%
engine = create_engine('sqlite:///user_profiles.db', echo=True)


data.to_sql('profiles', con=engine, if_exists='replace', index=False)
# Out:
# 2025-01-15 06:27:35,498 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2025-01-15 06:27:35,506 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("profiles")
# INFO:sqlalchemy.engine.Engine:PRAGMA main.table_info("profiles")
# 2025-01-15 06:27:35,510 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
# 2025-01-15 06:27:35,515 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("profiles")
# INFO:sqlalchemy.engine.Engine:PRAGMA temp.table_info("profiles")
# 2025-01-15 06:27:35,518 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
# 2025-01-15 06:27:35,522 INFO sqlalchemy.engine.Engine
# CREATE TABLE profiles (
# 	"CustomerID" TEXT,
# 	"Age" BIGINT,
# 	"Preferences" TEXT,
# 	"ProductQuality" BIGINT,
# 	"ServiceQuality" BIGINT,
# 	"PurchaseFrequency" BIGINT,
# 	"SatisfactionScore" BIGINT
# )
# INFO:sqlalchemy.engine.Engine:
# CREATE TABLE profiles (
# ...

# %%
def versatile_recommend(user_id, top_n=5):

    if user_id not in data['CustomerID'].values:
        return f"User with CustomerID {user_id} not found.", pd.DataFrame()


    user_index = data[data['CustomerID'] == user_id].index[0]

    # Calculate cosine similarity for preferences (content-based)
    preference_similarities = cosine_similarity(tfidf_matrix[user_index], tfidf_matrix).flatten()

    # Calculate similarity for numerical features (collaborative-based)
    numerical_similarities = cosine_similarity([data_scaled[user_index]], data_scaled).flatten()

    combined_similarities = 0.6 * preference_similarities + 0.4 * numerical_similarities

    similar_indices = combined_similarities.argsort()[-top_n-1:-1][::-1]

    recommendations = data.iloc[similar_indices]

    store_recommendations(user_id, recommendations[['CustomerID', 'Preferences']])

    return "Recommendations generated successfully.", recommendations[['CustomerID', 'Preferences', 'ProductQuality', 'ServiceQuality']]

# %%
def store_recommendations(user_id, recommendations):
    with engine.connect() as conn:
        recommendations['UserID'] = user_id
        recommendations['Timestamp'] = pd.Timestamp.now()

        recommendations.to_sql('recommendations_history', con=engine, if_exists='append', index=False)

# %%
def update_profile(customer_id, new_data):
    with engine.connect() as conn:
        query = f"SELECT * FROM profiles WHERE CustomerID = {customer_id}"
        result = conn.execute(query).fetchone()

        if result:
            for key, value in new_data.items():
                conn.execute(f"UPDATE profiles SET {key} = ? WHERE CustomerID = ?", (value, customer_id))
            return f"Profile for CustomerID {customer_id} updated."
        else:
            new_profile = pd.DataFrame([new_data])
            new_profile.to_sql('profiles', con=engine, if_exists='append', index=False)
            return f"New profile for CustomerID {customer_id} added."

def fetch_profile(customer_id):
    with engine.connect() as conn:
        query = f"SELECT * FROM profiles WHERE CustomerID = {customer_id}"
        result = conn.execute(query).fetchone()
        return dict(result) if result else None

# %%
def recommend_ui(customer_id, top_n):
    message, recommendations = versatile_recommend(customer_id, int(top_n))
    if isinstance(recommendations, pd.DataFrame):
        return message, recommendations.to_dict(orient='records')
    return message, []

def update_profile_ui(customer_id, age, preferences):
    new_data = {
        'CustomerID': customer_id,
        'Age': age,
        'Preferences': preferences
    }
    return update_profile(customer_id, new_data)

def fetch_profile_ui(customer_id):
    profile = fetch_profile(customer_id)
    if profile:
        return profile
    return f"Profile for CustomerID {customer_id} not found."

def main_function(operation, customer_id, top_n, age, preferences):
    if operation == "Generate Recommendations":
        return recommend_ui(customer_id, top_n)
    elif operation == "Update Profile":
        return update_profile_ui(customer_id, age, preferences)
    elif operation == "Fetch Profile":
        return fetch_profile_ui(customer_id)
    else:
        return "Invalid operation selected.", []

ui = gr.Interface(
    fn=main_function,
    inputs=[
        gr.Radio(
            choices=["Generate Recommendations", "Update Profile", "Fetch Profile"],
            label="Operation",
        ),
        gr.Textbox(label="Customer ID"),
        gr.Number(label="Top N Recommendations", value=5, precision=0),
        gr.Number(label="Age (for updating profile)", value=None, precision=0),
        gr.Textbox(label="Preferences (for updating profile)", placeholder="Enter preferences if updating profile")
    ],
    outputs=[
        gr.Textbox(label="Message"),
        gr.Dataframe(label="Output")
    ],
    live=True
)

ui.launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://54d13c83947ee56c9b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://54d13c83947ee56c9b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
